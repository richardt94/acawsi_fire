# %%
import geopandas as gpd

# %%
catchments = gpd.read_file('catchmentboundariesnsw/Catchment_Boundaries_NSW/Data/Catchments.shp')

# %%
catchments
# Out:
#     AREA  PERIMETER  CATCH_DLWC  CATCH_DL_1                             TAG  \
# 0    0.0   1.634547           2           1                           TWEED
# 1    0.0   9.368420           3           2                        CLARENCE
# 2    0.0   1.268349           4           3                       BRUNSWICK
# 3    0.0   4.200997           5           4                        RICHMOND
# 4    0.0  11.831130           6           5                       MACINTYRE
# 5    0.0   1.738137           7          10            MOONIE(NOT_NOTIFIED)
# 6    0.0  10.441211           8           9  CONDAMINE/CULGOA(NOT_NOTIFIED)
# 7    0.0   6.645475           9           8           WARREGO(NOT_NOTIFIED)
# 8    0.0  12.130951          10           7             PAROO(NOT_NOTIFIED)
# 9    0.0   8.707389          11           6        LAKE.FROME(NOT_NOTIFIED)
# 10   0.0   1.750880          12          11            COOPER(NOT_NOTIFIED)
# 11   0.0   7.121345          13          12            BULLOO(NOT_NOTIFIED)
# 12   0.0  10.442867          14          13               GWYDIR.RIVER.C.A.
# 13   0.0   4.868919          15          14                       BELLINGER
# 14   0.0   9.026421          16          15    LAKE.BANCANNIA(NOT_NOTIFIED)
# 15   0.0  13.559250          17          16                           NAMOI
# 16   0.0  21.128387          18          17                       MACQUARIE
# 17   0.0   6.928192          19          18              MACLEAY.RIVER.C.A.
# 18   0.0  22.912981          20          19           DARLING(NOT_NOTIFIED)
# 19   0.0   7.525229          21          20                     CASTLEREAGH
# 20   0.0   3.691666          22          21                        HASTINGS
# 21   0.0   5.365081          23          22                         MANNING
# 22   0.0   8.191641          24          23                          HUNTER
# 23   0.0   4.350104          25          24       PORT.STEPHENS/WALLIS.LAKE
# 24   0.0   6.026187          26          25     LAKE.VICTORIA(NOT_NOTIFIED)
# 25   0.0  21.880722          27          26                         LACHLAN
# 26   0.0  10.858280          28          27                      HAWKESBURY
# 27   0.0   2.052777          29          28   LAKE.MACQUARIE/TUGGERAH.LAKES
# 28   0.0   9.738925          30          29     PEACOCK.CREEK(NOT_NOTIFIED)
# 29   0.0  24.488857          31          30                    MURRUMBIDGEE
# 30   0.0   2.409425          32          31      PORT.JACKSON/GEORGES.RIVER
# 31   0.0   2.431056          33          32     LAKE.ILLAWARRA/PORT.HACKING
# 32   0.0   6.514390          34          33                      SHOALHAVEN
# 33   0.0  21.202961          35          34                          MURRAY
# 34   0.0   1.823396          36          35                     LAKE GEORGE
# 35   0.0   4.063441          37          36                           CLYDE
# 36   0.0   2.928811          38          37                          A.C.T.
# 37   0.0   2.086381          39          38                          MORUYA
# 38   0.0   5.586288          40          39                           SNOWY
# 39   0.0   2.817144          41          40                          TUROSS
# 40   0.0   2.895517          42          41                            BEGA
# 41   0.0   3.348418          43          42                         TOWAMBA
# 42   0.0   2.218759          44          43                           GENOA
# 43   0.0   0.078282          45          44                           GENOA
#
#     SHAPE_Leng  SHAPE_Area                                           geometry
# 0     1.634547    0.099379  POLYGON ((153.10806 -28.35751, 153.10941 -28.3...
# 1     9.368419    2.073364  POLYGON ((152.01489 -28.89820, 152.01677 -28.8...
# 2     1.268349    0.047064  POLYGON ((153.58377 -28.25711, 153.58481 -28.2...
# 3     4.200997    0.650226  POLYGON ((152.67490 -28.32683, 152.67934 -28.3...
# 4    11.831130    2.242529  POLYGON ((149.42906 -28.64074, 149.42906 -28.6...
# 5     1.738136    0.069114  POLYGON ((148.53835 -28.99844, 148.95897 -28.9...
# 6    10.441211    2.406141  POLYGON ((146.30302 -28.99845, 148.53835 -28.9...
# 7     6.645476    1.061240  POLYGON ((145.53128 -28.99846, 146.30302 -28.9...
# 8    12.130952    3.787720  POLYGON ((144.07784 -28.99860, 145.53128 -28.9...
# 9     8.707388    1.827686  POLYGON ((141.19182 -28.99855, 141.20110 -29.0...
# 10    1.750880    0.058005  POLYGON ((141.19182 -28.99855, 141.94698 -28.9...
# 11    7.121345    1.896559  POLYGON ((141.94698 -28.99878, 144.07784 -28.9...
# 12   10.442867    2.479270  POLYGON ((148.71181 -29.31340, 148.71292 -29.3...
# 13    4.868918    0.324869  POLYGON ((153.36150 -29.47261, 153.36021 -29.4...
# 14    9.026420    2.186512  POLYGON ((143.55180 -30.00833, 143.55971 -30.0...
# 15   13.559250    3.958175  POLYGON ((148.36528 -29.78066, 148.38826 -29.7...
# 16   21.128389    7.133665  POLYGON ((145.95358 -30.05379, 145.95560 -30.0...
# 17    6.928191    1.076095  POLYGON ((152.39688 -30.44301, 152.39325 -30.4...
# 18   22.912982   10.775363  POLYGON ((145.13884 -30.47676, 145.14035 -30.4...
# 19    7.525229    1.648247  POLYGON ((149.86594 -31.68009, 149.86223 -31.6...
# 20    3.691665    0.428890  POLYGON ((152.98001 -31.16589, 152.97720 -31.1...
# 21    5.365082    0.778612  POLYGON ((151.65425 -31.33131, 151.65637 -31.3...
# 22    8.191641    2.054420  POLYGON ((151.15671 -31.62837, 151.16342 -31.6...
# 23    4.350104    0.430216  POLYGON ((152.57100 -31.99804, 152.56715 -32.0...
# 24    6.026187    0.874474  POLYGON ((141.14529 -32.16294, 141.15305 -32.1...
# 25   21.880723    8.370356  POLYGON ((146.46530 -32.34747, 146.46646 -32.3...
# 26   10.858280    2.146334  POLYGON ((150.36209 -32.84464, 150.36975 -32.8...
# 27    2.052776    0.152456  POLYGON ((151.73039 -32.98830, 151.73102 -32.9...
# 28    9.738925    2.082835  POLYGON ((143.92546 -32.96297, 143.92989 -32.9...
# 29   24.488859    6.779618  POLYGON ((146.75085 -33.81931, 146.75684 -33.8...
# 30    2.409424    0.177808  POLYGON ((151.31342 -33.68080, 151.30896 -33.6...
# 31    2.431055    0.078088  POLYGON ((151.15735 -34.07044, 151.16893 -34.0...
# 32    6.514390    0.712792  POLYGON ((150.61171 -34.58541, 150.62494 -34.5...
# 33   21.202962    3.516452  POLYGON ((143.21889 -34.72971, 143.21916 -34.7...
# 34    1.823396    0.093163  POLYGON ((149.54169 -34.98763, 149.54166 -34.9...
# 35    4.063443    0.340607  POLYGON ((150.78015 -34.96479, 150.77917 -34.9...
# 36    2.928811    0.234389  POLYGON ((149.39813 -35.32611, 149.39108 -35.3...
# 37    2.086381    0.148154  POLYGON ((150.15242 -35.88343, 150.14987 -35.8...
# 38    5.586288    0.899531  POLYGON ((148.43101 -36.17595, 148.43338 -36.1...
# 39    2.817144    0.216644  POLYGON ((149.67256 -35.98846, 149.67831 -35.9...
# 40    2.895517    0.285518  POLYGON ((149.51231 -36.41738, 149.51740 -36.4...
# 41    3.348419    0.219192  POLYGON ((149.93015 -36.87830, 149.93095 -36.8...
# 42    2.218759    0.115227  POLYGON ((149.38853 -37.02958, 149.38884 -37.0...
# 43    0.078282    0.000343  POLYGON ((149.13463 -37.17409, 149.11172 -37.1...

# %%
rivers = gpd.read_file('rivers_NSW/rivers_NSW.shp')

# %%
rivers
# Out:
#        OBJECTID  HydroID  AHGFFType          Name Hierarchy      Perennial  \
# 0             1  2328036          1   TWEED RIVER     Major      Perennial
# 1             2  2328860          1   TWEED RIVER     Major      Perennial
# 2             3  2330071          1   TWEED RIVER     Major      Perennial
# 3             4  2330392          1   TWEED RIVER     Major      Perennial
# 4             5  2331206          1   TWEED RIVER     Major      Perennial
# ...         ...      ...        ...           ...       ...            ...
# 18666     18667  2513788          1  SPRING CREEK     Major  Non Perennial
# 18667     18668  2514350          1  SPRING CREEK     Major  Non Perennial
# 18668     18669  2514806          1  SPRING CREEK     Major  Non Perennial
# 18669     18670  2515026          1  SPRING CREEK     Major  Non Perennial
# 18670     18671  2515875          1  SPRING CREEK     Major  Non Perennial
#
#        AusHydroID  AusHydroEr  SegmentNo  DrainID  ...     AttrRel  \
# 0          533013           1     878665  7024331  ...  2003-01-01
# 1          531967           1     878971  7024561  ...  2003-01-01
# 2          530751           2     879272  7024763  ...  2003-01-01
# 3          528886           1     879689  7025029  ...  2003-01-01
# 4          528360           1     879825  7025113  ...  2003-01-01
# ...           ...         ...        ...      ...  ...         ...
# 18666      285274           1     973593  6874909  ...  2003-01-01
# 18667      284680           1     973825  6874977  ...  2003-01-01
# 18668      284053           1     974245  6875092  ...  2003-01-01
# 18669      283486           1     974539  6875182  ...  2003-01-01
# 18670      283206           1     974675  6875229  ...  2003-01-01
#
#                  AttrSource  PlanAcc  Symbol  TextNote    GeodesLen  \
# 0      GEOSCIENCE AUSTRALIA      125      92      None  1539.995392
# 1      GEOSCIENCE AUSTRALIA      125      92      None  1571.498484
# 2      GEOSCIENCE AUSTRALIA      125      92      None  2218.666737
# 3      GEOSCIENCE AUSTRALIA      125      92      None   647.185185
# 4      GEOSCIENCE AUSTRALIA      125      92      None  1664.446748
# ...                     ...      ...     ...       ...          ...
# 18666  GEOSCIENCE AUSTRALIA      125      92      None  1007.062410
# 18667  GEOSCIENCE AUSTRALIA      125      92      None  1649.136693
# 18668  GEOSCIENCE AUSTRALIA      125      92      None  1284.185202
# 18669  GEOSCIENCE AUSTRALIA      125      92      None   554.398192
# 18670  GEOSCIENCE AUSTRALIA      125      92      None  2115.741604
#
#          UpstrGeoLn    UpstrDArea  Shape_Leng  \
# 0      1.117857e+06  1.082316e+09    0.014571
# 1      1.114809e+06  1.079731e+09    0.014571
# 2      9.923000e+05  9.627806e+08    0.020607
# 3      9.812125e+05  9.518333e+08    0.006036
# 4      9.805653e+05  9.516973e+08    0.015607
# ...             ...           ...         ...
# 18666  2.266020e+04  2.019127e+07    0.009571
# 18667  1.788819e+04  1.663898e+07    0.015607
# 18668  1.366276e+04  1.381038e+07    0.012071
# 18669  9.969959e+03  1.111362e+07    0.005000
# 18670  6.205222e+03  7.430793e+06    0.019571
#
#                                                 geometry
# 0      LINESTRING (153.55125 -28.17875, 153.54875 -28...
# 1      LINESTRING (153.55625 -28.19125, 153.55625 -28...
# 2      LINESTRING (153.56375 -28.20875, 153.56375 -28...
# 3      LINESTRING (153.56125 -28.21375, 153.56125 -28...
# 4      LINESTRING (153.55375 -28.22625, 153.55625 -28...
# ...                                                  ...
# 18666  LINESTRING (141.51125 -31.56375, 141.51375 -31...
# 18667  LINESTRING (141.50375 -31.57625, 141.50625 -31...
# 18668  LINESTRING (141.50375 -31.58625, 141.50625 -31...
# 18669  LINESTRING (141.50375 -31.59125, 141.50375 -31...
# 18670  LINESTRING (141.49875 -31.60875, 141.49875 -31...
#
# [18671 rows x 31 columns]

# %%
import ipyleaflet as L

# %%
from ipywidgets import Label, Layout, VBox

label = Label(layout=Layout(width='100%'))

map_catchments = L.Map(center=(-30,130),zoom=3)

catch_layer = L.GeoData(geo_dataframe = catchments,
                   style={'color': 'black', 'fillColor': 'red', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'Countries')

def catch_hover(event=None, feature=None, id=None, properties=None):
    label.value = properties['TAG']
    
catch_layer.on_hover(catch_hover)

river_layer = L.GeoData(geo_dataframe = rivers,
                   style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'Countries')

map_catchments.add_layer(catch_layer)
map_catchments.add_layer(river_layer)

VBox([map_catchments,label])
# Out:
# VBox(children=(Map(center=[-30, 130], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_titl…

# %%
catch_geom = catchments[catchments['TAG']=='MACLEAY.RIVER.C.A.']['geometry']

# %%
import xarray as xr

awra_daily = xr.open_dataset('qtot_2020_Actual_day.nc')

#select February (so far)
awra_daily = awra_daily.sel(time=slice('2020-02-01','2020-02-11'))

#sum runoff over the month
awra_monthly = awra_daily.sum(dim='time')


geoms = catchments['geometry']

nsw = geoms.unary_union

# %%
awra_daily = xr.open_dataset('qtot_2020_Actual_day.nc')

# %%
# awra_daily = awra_daily.sel(time=slice('2020-02-01','2020-02-11'))

# %%
awra_monthly = awra_daily.sum(dim='time')

# %%
awra_monthly.qtot.plot(figsize=(13,8))

# %%
geoms = catchments['geometry']

# %%
nsw = geoms.unary_union

# %%
from affine import Affine
transform = Affine.translation(112,-10)*Affine.scale(0.05,-0.05)

# %%
from rasterio import features

# %%
catch_mask = features.geometry_mask([nsw],awra_monthly.qtot.shape,transform,invert=True)

# %%
import matplotlib.pyplot as plt
plt.imshow(catch_mask.astype(float))

# %%
awra_nsw_qtot = awra_monthly.where(catch_mask).qtot

# %%
awra_nsw_qtot.dropna(dim='latitude',how='all').dropna(dim='longitude',how='all').plot(robust=True)

# %%
awra_nsw_qtot = awra_nsw_qtot.dropna(dim='latitude',how='all').dropna(dim='longitude',how='all')

# %%
awra_nsw_qtot.mean()
# Out:
# <xarray.DataArray 'qtot' ()>
# array(5.79882368)

# %%
awra_nsw_qtot.quantile(q=0.95)
# Out:
# <xarray.DataArray 'qtot' ()>
# array(31.20820312)
# Coordinates:
#     quantile  float64 0.95

# %% [markdown]
# ## Open GEEBAM GeoTIFF

# %%
GEEBAM = xr.open_rasterio('/g/data/oe9/user/rlt118/GEEBAM_v3p0_dNBR_Classes.tif')

# %%
#resample GEEBAM to be a manageable resolution
import numpy as np
GEEBAM_lr = GEEBAM.reindex(
        x = np.arange(GEEBAM.x.min(),GEEBAM.x.max(),0.005),
        y = np.arange(GEEBAM.y.max(),GEEBAM.y.min(),-0.005),
        method = 'nearest',
        tolerance = GEEBAM.res[0]   
)

# %%
GEEBAM_lr = GEEBAM_lr.isel(band=0)

# %%
GEENSW = GEEBAM_lr.sel(x=slice(nsw.bounds[0],nsw.bounds[2]),y=slice(nsw.bounds[3],nsw.bounds[1]))

# %%
nsw.bounds
# Out:
# (141.001098683951, -37.505176496964566, 153.63888555144706, -28.15702057996066)

# %%
GEENSW.plot()

# %%
GEENSWtrans = Affine.translation(GEENSW.x[0].data,GEENSW.y[0].data)*Affine.scale(0.005,-0.005)

# %%
gmask = features.geometry_mask([nsw],GEENSW.shape,GEENSWtrans,invert=True)

# %%
GEENSW = GEENSW.where(gmask)

# %%
GEENSW.plot()

# %%
from simpledbf import Dbf5
# Out:
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
dbf = Dbf5('/g/data/oe9/user/rlt118/GEEBAM_v3p0_dNBR_Classes.tif.vat.dbf')

# %%
GEEBAM_class_table = dbf.to_dataframe()

# %%
GEEBAM_class_table
# Out:
#      Value       Count  vegForm_SV  \
# 0        0  23389781.0          20
# 1        1   2280011.0           1
# 2        2   3832537.0           1
# 3        3   3900925.0           1
# 4        4   3491281.0           1
# ..     ...         ...         ...
# 145    153    181773.0          19
# 146    154     75858.0          19
# 147    155     34045.0          19
# 148    156       105.0           7
# 149    157    534651.0          19
#
#                                          vegFORM  dNBR  GEEBAMclas  \
# 0                                     Unassigned     0         254
# 1                                     Non-native     1         254
# 2                                     Non-native     2         254
# 3                                     Non-native     3         254
# 4                                     Non-native     4         254
# ..                                           ...   ...         ...
# 145                               Alpine Complex     8           4
# 146                               Alpine Complex     2           1
# 147                               Alpine Complex     1           1
# 148  Semi-arid Woodlands (Shrubby sub-formation)     9           0
# 149                               Alpine Complex     9           4
#
#                 GEEBAMv3p0   verDate
# 0         Not yet assessed  20200203
# 1         Not yet assessed  20200203
# 2         Not yet assessed  20200203
# 3         Not yet assessed  20200203
# 4         Not yet assessed  20200203
# ..                     ...       ...
# 145  Canopy fully affected  20200203
# 146          Little change  20200203
# 147          Little change  20200203
# 148       Not yet assessed  20200203
# 149  Canopy fully affected  20200203
#
# [150 rows x 8 columns]

# %%
GEEBAM_class_table['GEEBAMclas'].unique()
# Out:
# array([254,   3,   2,   4,   1,   0])

# %%
import pandas as pd
tiffmap = pd.Series(GEEBAM_class_table.GEEBAMclas.values,index=GEEBAM_class_table.Value).to_dict()
tiffmap[253] = 253

# %%
tiffmap[253]
# Out:
# 253

# %%
severity_dict = {
    0 : 2,
    1 : 1,
    2 : 2,
    3 : 3,
    4 : 4,
    253 : 0,
}

@np.vectorize
def tiffmap_float(val):
    if np.isnan(val):
        return val
    idx = int(val)
    sev_cat = tiffmap[idx] if tiffmap[idx] != 254 else 0
    return severity_dict[sev_cat]
    
    
burntNSW = xr.apply_ufunc(tiffmap_float,GEENSW)

# %%
burntNSW.plot()

# %%
burntNSW = burntNSW.rename({'x':'longitude','y':'latitude'})

# %%
awra_nsw_qtot = awra_nsw_qtot.reindex(longitude=burntNSW.longitude,latitude=burntNSW.latitude,method='nearest',tolerance=0.05)

# %%
risk_map = awra_nsw_qtot*burntNSW
risk_map.plot(vmin=0,vmax=250,figsize=(15,11))

# %%
risk_map.quantile(0.95)
# Out:
# <xarray.DataArray ()>
# array(62.09375)
# Coordinates:
#     quantile  float64 0.95

# %%
len(catchments)
# Out:
# 44

# %%
rmap_transform = Affine.translation(risk_map.longitude.min(),risk_map.latitude.max())*Affine.scale(0.005,-0.005)

# %%
def catch_to_risk(catchment_poly):
    #mask the risk map to the shape of the catchment
    mask = features.geometry_mask([catchment_poly],risk_map.shape,rmap_transform,invert=True)
    mean_risk = risk_map.where(mask).mean()
    quantiles = risk_map.where(mask).quantile([0.5,0.95])
    
    result = np.array([mean_risk,*quantiles.data])
    result[np.isnan(result)] = 0
    return result

# %%
catch_to_risk(catchments.iloc[43].geometry)
# Out:
# array([13.515625, 13.515625, 13.515625])

# %%
risk_results = np.stack(catchments.geometry.apply(catch_to_risk))
# Out:
# /g/data/oe9/software/miniconda3/lib/python3.7/site-packages/xarray/core/nanops.py:140: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /g/data/oe9/software/miniconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: All-NaN slice encountered
#   overwrite_input=overwrite_input, interpolation=interpolation

# %%
catchments['mean_risk'] = risk_results[:,0]
catchments['median_risk'] = risk_results[:,1]
catchments['p95_risk'] = risk_results[:,2]

# %%
catchments
# Out:
#     AREA  PERIMETER  CATCH_DLWC  CATCH_DL_1                             TAG  \
# 0    0.0   1.634547           2           1                           TWEED
# 1    0.0   9.368420           3           2                        CLARENCE
# 2    0.0   1.268349           4           3                       BRUNSWICK
# 3    0.0   4.200997           5           4                        RICHMOND
# 4    0.0  11.831130           6           5                       MACINTYRE
# 5    0.0   1.738137           7          10            MOONIE(NOT_NOTIFIED)
# 6    0.0  10.441211           8           9  CONDAMINE/CULGOA(NOT_NOTIFIED)
# 7    0.0   6.645475           9           8           WARREGO(NOT_NOTIFIED)
# 8    0.0  12.130951          10           7             PAROO(NOT_NOTIFIED)
# 9    0.0   8.707389          11           6        LAKE.FROME(NOT_NOTIFIED)
# 10   0.0   1.750880          12          11            COOPER(NOT_NOTIFIED)
# 11   0.0   7.121345          13          12            BULLOO(NOT_NOTIFIED)
# 12   0.0  10.442867          14          13               GWYDIR.RIVER.C.A.
# 13   0.0   4.868919          15          14                       BELLINGER
# 14   0.0   9.026421          16          15    LAKE.BANCANNIA(NOT_NOTIFIED)
# 15   0.0  13.559250          17          16                           NAMOI
# 16   0.0  21.128387          18          17                       MACQUARIE
# 17   0.0   6.928192          19          18              MACLEAY.RIVER.C.A.
# 18   0.0  22.912981          20          19           DARLING(NOT_NOTIFIED)
# 19   0.0   7.525229          21          20                     CASTLEREAGH
# 20   0.0   3.691666          22          21                        HASTINGS
# 21   0.0   5.365081          23          22                         MANNING
# 22   0.0   8.191641          24          23                          HUNTER
# 23   0.0   4.350104          25          24       PORT.STEPHENS/WALLIS.LAKE
# 24   0.0   6.026187          26          25     LAKE.VICTORIA(NOT_NOTIFIED)
# 25   0.0  21.880722          27          26                         LACHLAN
# 26   0.0  10.858280          28          27                      HAWKESBURY
# 27   0.0   2.052777          29          28   LAKE.MACQUARIE/TUGGERAH.LAKES
# 28   0.0   9.738925          30          29     PEACOCK.CREEK(NOT_NOTIFIED)
# 29   0.0  24.488857          31          30                    MURRUMBIDGEE
# 30   0.0   2.409425          32          31      PORT.JACKSON/GEORGES.RIVER
# 31   0.0   2.431056          33          32     LAKE.ILLAWARRA/PORT.HACKING
# 32   0.0   6.514390          34          33                      SHOALHAVEN
# 33   0.0  21.202961          35          34                          MURRAY
# 34   0.0   1.823396          36          35                     LAKE GEORGE
# 35   0.0   4.063441          37          36                           CLYDE
# 36   0.0   2.928811          38          37                          A.C.T.
# 37   0.0   2.086381          39          38                          MORUYA
# 38   0.0   5.586288          40          39                           SNOWY
# 39   0.0   2.817144          41          40                          TUROSS
# 40   0.0   2.895517          42          41                            BEGA
# 41   0.0   3.348418          43          42                         TOWAMBA
# 42   0.0   2.218759          44          43                           GENOA
# 43   0.0   0.078282          45          44                           GENOA
#
#     SHAPE_Leng  SHAPE_Area                                           geometry  \
# 0     1.634547    0.099379  POLYGON ((153.10806 -28.35751, 153.10941 -28.3...
# 1     9.368419    2.073364  POLYGON ((152.01489 -28.89820, 152.01677 -28.8...
# 2     1.268349    0.047064  POLYGON ((153.58377 -28.25711, 153.58481 -28.2...
# 3     4.200997    0.650226  POLYGON ((152.67490 -28.32683, 152.67934 -28.3...
# 4    11.831130    2.242529  POLYGON ((149.42906 -28.64074, 149.42906 -28.6...
# 5     1.738136    0.069114  POLYGON ((148.53835 -28.99844, 148.95897 -28.9...
# 6    10.441211    2.406141  POLYGON ((146.30302 -28.99845, 148.53835 -28.9...
# 7     6.645476    1.061240  POLYGON ((145.53128 -28.99846, 146.30302 -28.9...
# 8    12.130952    3.787720  POLYGON ((144.07784 -28.99860, 145.53128 -28.9...
# 9     8.707388    1.827686  POLYGON ((141.19182 -28.99855, 141.20110 -29.0...
# 10    1.750880    0.058005  POLYGON ((141.19182 -28.99855, 141.94698 -28.9...
# 11    7.121345    1.896559  POLYGON ((141.94698 -28.99878, 144.07784 -28.9...
# 12   10.442867    2.479270  POLYGON ((148.71181 -29.31340, 148.71292 -29.3...
# 13    4.868918    0.324869  POLYGON ((153.36150 -29.47261, 153.36021 -29.4...
# 14    9.026420    2.186512  POLYGON ((143.55180 -30.00833, 143.55971 -30.0...
# 15   13.559250    3.958175  POLYGON ((148.36528 -29.78066, 148.38826 -29.7...
# 16   21.128389    7.133665  POLYGON ((145.95358 -30.05379, 145.95560 -30.0...
# 17    6.928191    1.076095  POLYGON ((152.39688 -30.44301, 152.39325 -30.4...
# 18   22.912982   10.775363  POLYGON ((145.13884 -30.47676, 145.14035 -30.4...
# 19    7.525229    1.648247  POLYGON ((149.86594 -31.68009, 149.86223 -31.6...
# 20    3.691665    0.428890  POLYGON ((152.98001 -31.16589, 152.97720 -31.1...
# 21    5.365082    0.778612  POLYGON ((151.65425 -31.33131, 151.65637 -31.3...
# 22    8.191641    2.054420  POLYGON ((151.15671 -31.62837, 151.16342 -31.6...
# 23    4.350104    0.430216  POLYGON ((152.57100 -31.99804, 152.56715 -32.0...
# 24    6.026187    0.874474  POLYGON ((141.14529 -32.16294, 141.15305 -32.1...
# 25   21.880723    8.370356  POLYGON ((146.46530 -32.34747, 146.46646 -32.3...
# 26   10.858280    2.146334  POLYGON ((150.36209 -32.84464, 150.36975 -32.8...
# 27    2.052776    0.152456  POLYGON ((151.73039 -32.98830, 151.73102 -32.9...
# 28    9.738925    2.082835  POLYGON ((143.92546 -32.96297, 143.92989 -32.9...
# 29   24.488859    6.779618  POLYGON ((146.75085 -33.81931, 146.75684 -33.8...
# 30    2.409424    0.177808  POLYGON ((151.31342 -33.68080, 151.30896 -33.6...
# 31    2.431055    0.078088  POLYGON ((151.15735 -34.07044, 151.16893 -34.0...
# 32    6.514390    0.712792  POLYGON ((150.61171 -34.58541, 150.62494 -34.5...
# 33   21.202962    3.516452  POLYGON ((143.21889 -34.72971, 143.21916 -34.7...
# 34    1.823396    0.093163  POLYGON ((149.54169 -34.98763, 149.54166 -34.9...
# 35    4.063443    0.340607  POLYGON ((150.78015 -34.96479, 150.77917 -34.9...
# 36    2.928811    0.234389  POLYGON ((149.39813 -35.32611, 149.39108 -35.3...
# 37    2.086381    0.148154  POLYGON ((150.15242 -35.88343, 150.14987 -35.8...
# 38    5.586288    0.899531  POLYGON ((148.43101 -36.17595, 148.43338 -36.1...
# 39    2.817144    0.216644  POLYGON ((149.67256 -35.98846, 149.67831 -35.9...
# 40    2.895517    0.285518  POLYGON ((149.51231 -36.41738, 149.51740 -36.4...
# 41    3.348419    0.219192  POLYGON ((149.93015 -36.87830, 149.93095 -36.8...
# 42    2.218759    0.115227  POLYGON ((149.38853 -37.02958, 149.38884 -37.0...
# 43    0.078282    0.000343  POLYGON ((149.13463 -37.17409, 149.11172 -37.1...
#
#     mean_risk  median_risk    p95_risk
# 0    5.000151     0.000000    0.000000
# 1   58.685541     0.000000  278.875000
# 2    0.000000     0.000000    0.000000
# 3   27.016911     0.000000  160.054688
# 4    0.551505     0.000000    0.000000
# 5    0.000000     0.000000    0.000000
# 6    0.000000     0.000000    0.000000
# 7    0.000000     0.000000    0.000000
# 8    0.000000     0.000000    0.000000
# 9    0.000000     0.000000    0.000000
# 10   0.000000     0.000000    0.000000
# 11   0.000000     0.000000    0.000000
# 12   0.233562     0.000000    0.000000
# 13  34.569156     0.000000  199.429688
# 14   0.000000     0.000000    0.000000
# 15   0.177781     0.000000    0.000000
# 16   0.065067     0.000000    0.000000
# 17  15.444034     0.000000   65.437500
# 18   0.000000     0.000000    0.000000
# 19   0.001479     0.000000    0.000000
# 20  32.804361     0.000000  167.281250
# 21  39.683431     0.000000  229.664062
# 22   0.935050     0.000000    7.875000
# 23  10.533697     0.000000   33.671875
# 24   0.000000     0.000000    0.000000
# 25   0.001033     0.000000    0.000000
# 26  33.162229     0.000000  167.132812
# 27   1.114943     0.000000    0.000000
# 28   0.000000     0.000000    0.000000
# 29   1.615305     0.000000    4.101562
# 30   0.149013     0.000000    0.000000
# 31   0.095995     0.000000    0.000000
# 32  19.948836     0.000000   92.312500
# 33   1.330464     0.000000    5.265625
# 34   0.380418     0.000000    0.000000
# 35  51.888821    51.546875  118.812500
# 36   5.408927     0.000000   29.953125
# 37  30.233114    32.937500   72.687500
# 38   2.621061     0.000000    2.203125
# 39  22.206509    22.804688   48.875000
# 40   7.049260     0.000000   29.277734
# 41   5.245237     2.859375   20.562500
# 42   6.405953     4.562500   17.984375
# 43  13.515625    13.515625   13.515625

# %%
catchments.to_file('risk_results.shp')
# Out:
# WARNING:fiona._env:Normalized/laundered field name: 'median_risk' to 'median_ris'
